# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanaAnnaman/MLDATA/blob/main/groupprojecrt_election.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#matplotlib incline

# %%
alana1 = pd.read_csv('https://raw.githubusercontent.com/glopez21/ML-Data/main/2020%20November%20General%20Election%20-%20Turnout%20Rates.csv')

# %%
alana1.head()
# Out:
#            State  ... State Abv
# 0  United States  ...       NaN
# 1        Alabama  ...        AL
# 2         Alaska  ...        AK
# 3        Arizona  ...        AZ
# 4       Arkansas  ...        AR
#
# [5 rows x 15 columns]

# %%
alana1.shape #52 rows , 15 colums
# Out:
# (52, 15)

# %%
alana1.index
# Out:
# RangeIndex(start=0, stop=52, step=1)

# %%
alana1.info
# Out:
# <bound method DataFrame.info of                    State  ... State Abv
# 0          United States  ...       NaN
# 1                Alabama  ...        AL
# 2                 Alaska  ...        AK
# 3                Arizona  ...        AZ
# 4               Arkansas  ...        AR
# 5             California  ...        CA
# 6               Colorado  ...        CO
# 7            Connecticut  ...        CT
# 8               Delaware  ...        DE
# 9   District of Columbia  ...        DC
# 10               Florida  ...        FL
# 11               Georgia  ...        GA
# 12                Hawaii  ...        HI
# 13                 Idaho  ...        ID
# 14              Illinois  ...        IL
# 15               Indiana  ...        IN
# 16                  Iowa  ...        IA
# 17                Kansas  ...        KS
# 18              Kentucky  ...        KY
# 19             Louisiana  ...        LA
# 20                 Maine  ...        ME
# 21              Maryland  ...        MD
# ...

# %%
alana1[alana1['Total Ballots Counted (Estimate)']==alana1['Total Ballots Counted (Estimate)'].max()] #shows that nebraska has the highest total ballots counted
# Out:
#        State                                 Source  ... Overseas Eligible State Abv
# 28  Nebraska  https://electionresults.nebraska.gov/  ...               NaN        NE
#
# [1 rows x 15 columns]

# %%
alana1['Total Ballots Counted (Estimate)'].max() #all ballots but max value of it
# Out:
# '948,852'

# %%
alana1['VEP Turnout Rate'].max()
# Out:
# '79.9%'

# %%
alana1['VEP Turnout Rate'].min()
# Out:
# '55.0%'

# %%
alana1.sort_values(by=['VEP Turnout Rate'], ascending=False) #highest turnout rate
# Out:
#                    State  ... State Abv
# 24             Minnesota  ...        MN
# 20                 Maine  ...        ME
# 16                  Iowa  ...        IA
# 6               Colorado  ...        CO
# 50             Wisconsin  ...        WI
# 48            Washington  ...        WA
# 30         New Hampshire  ...        NH
# 38                Oregon  ...        OR
# 46               Vermont  ...        VT
# 23              Michigan  ...        MI
# 22         Massachusetts  ...        MA
# 27               Montana  ...        MT
# 31            New Jersey  ...        NJ
# 34        North Carolina  ...        NC
# 10               Florida  ...        FL
# 47              Virginia  ...        VA
# 7            Connecticut  ...        CT
# 21              Maryland  ...        MD
# 39          Pennsylvania  ...        PA
# 8               Delaware  ...        DE
# 2                 Alaska  ...        AK
# 36                  Ohio  ...        OH
# ...

# %%
alana1.head()
# Out:
#            State  ... State Abv
# 0  United States  ...       NaN
# 1        Alabama  ...        AL
# 2         Alaska  ...        AK
# 3        Arizona  ...        AZ
# 4       Arkansas  ...        AR
#
# [5 rows x 15 columns]

# %%
alana1.sort_values(by=['Prison'], ascending=False) #shows that florida has the highest prison rate
# Out:
#                    State  ... State Abv
# 10               Florida  ...        FL
# 17                Kansas  ...        KS
# 24             Minnesota  ...        MN
# 16                  Iowa  ...        IA
# 13                 Idaho  ...        ID
# 22         Massachusetts  ...        MA
# 32            New Mexico  ...        NM
# 49         West Virginia  ...        WV
# 45                  Utah  ...        UT
# 11               Georgia  ...        GA
# 8               Delaware  ...        DE
# 28              Nebraska  ...        NE
# 12                Hawaii  ...        HI
# 36                  Ohio  ...        OH
# 39          Pennsylvania  ...        PA
# 33              New York  ...        NY
# 2                 Alaska  ...        AK
# 3                Arizona  ...        AZ
# 14              Illinois  ...        IL
# 23              Michigan  ...        MI
# 47              Virginia  ...        VA
# 34        North Carolina  ...        NC
# ...

# %%
alana1['Prison'].value_counts().sort_index().plot.line() #shows a line graph of the highest prison rate
